# %% [markdown]
# <a href="https://colab.research.google.com/github/NivethaAshokkumarG/Python-Core-Mechanics-String-Manipulation-Immutable-Sequence-Types/blob/main/Nivetha's_Python_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **# Python Assignment 1 - Data Structures - Strings & Tuples**

# %% [markdown]
# ### **Strings (Concatenation, Slicing, and Other Methods) :**

# %%
from re import T
#1. String Concatenation:

string1 = "Hello"
string2 = input("Enter your name : ")
string3 = print(f"{string1} {string2}")

print(f"{string1} {string2} , Welcome to Python Programming")



#2. String Slicing and Indexing:

#a. Print the first character of the string.

print(f"The First Character of the string is : {string2[0:1]}")

#b. Print the last character of the string.

print(f"The Last Character of the string is : {string2[-1]}")

# c. Print the first 5 characters of the string.

print(f"The First 5 Character of the string is : {string2[0:6]}")

# d. Print the last 11 characters of the string.

print(f"The First 11 Character of the string is : {string2[-11:]}")


#e. Print the string in reverse.

print(f"Reverse in string is : {string2[::-1]}")

string4 =" Welcome to python programming"

#f. Use slicing and print the word “Python” from the existing string.

print(f"used slicing and print the word Python: {string4[12:18]}")


#3. String Methods:



strM =  " Python beginner tutorial"

# To Upper Case
print(f"the sentence to Uppercase {strM.upper()}")

# To Lower Case
print(f"the sentence to Lowercase {strM.lower()}")

# To Capitalized
print(f"Capitalized {strM.capitalize()}")

# occurances Finding

print(f"Total number of letter t Occurance : {strM.lower().count("t")}")


# Replacing Occurance

print(f"Replace with Data Analytics : {strM.replace("Python" , "Data Analytics")}")
# Out:
# Enter your name : Nivi
# Hello Nivi
# Hello Nivi , Welcome to Python Programming
# The First Character of the string is : N
# The Last Character of the string is : i
# The First 5 Character of the string is : Nivi
# The First 11 Character of the string is : Nivi
# Reverse in string is : iviN
# used slicing and print the word Python: python
# the sentence to Uppercase  PYTHON BEGINNER TUTORIAL
# the sentence to Lowercase  python beginner tutorial
# Capitalized  python beginner tutorial
# Total number of letter t Occurance : 3
# Replace with Data Analytics :  Data Analytics beginner tutorial
# 1st Tuple : (10, 20, 30) , 2nd Tuple : (40, 50, 60)
# Concatinating to Tuple : (10, 20, 30, 40, 50, 60)
# Accessin the  3rd Element : 30
# Accessing the First three Elements :(10, 20, 30)
# Accessing the last three Elements :(40, 50, 60)

# %% [markdown]
# # **Tuples (Creation, Modification and Access) :**

# %%
# Tuples (Creation, Modification and Access) :

first_tuple = (10,20,30)
second_tuple = (40,50,60)
print(f"1st Tuple : {first_tuple} , 2nd Tuple : {second_tuple}")


t_combine = first_tuple + second_tuple
print(f"Concatinating to Tuple : {t_combine}")


print(f"Accessin the  3rd Element : {t_combine[2]}")

print(f"Accessing the First three Elements :{t_combine[0:3]}")

print(f"Accessing the last three Elements :{t_combine[-3:]}")
